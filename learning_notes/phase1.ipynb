# %% [markdown]
# to study:
# -- general --
# about Tesseract
#
# -- in preprocess.py --
# 1. cv2.medianBlur(gray, 3) # denoise and sharpen a bit
# 2. cv2.adaptiveThreshoold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRES_BINARY, 31, 11)
#
# -- in ocr_engine.py --
